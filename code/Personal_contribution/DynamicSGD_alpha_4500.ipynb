# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4

# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 4500, 1e-6  # Scaling factor and small constant

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop


H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        computation_start_time = time.time()
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:03<00:00, 43.4MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1, Iteration 1: H_t = 64, G_t = 0.0069, σ_t^2 = 0.1247
# Epoch 1, Iteration 2: H_t = 4, G_t = -0.0002, σ_t^2 = 0.1469
# Epoch 1, Iteration 3: H_t = 64, G_t = 0.0078, σ_t^2 = 0.1306
# Epoch 1, Iteration 4: H_t = 64, G_t = 0.0057, σ_t^2 = 0.2113
# Epoch 1, Iteration 5: H_t = 64, G_t = 0.0260, σ_t^2 = 0.5923
#     Worker 0: Train Loss: 4.5970, Train Accuracy: 1.57%
#     Worker 1: Train Loss: 4.5971, Train Accuracy: 1.45%
#     Worker 2: Train Loss: 4.5950, Train Accuracy: 1.68%
#     Worker 3: Train Loss: 4.5969, Train Accuracy: 1.53%
# Epoch 1: Test Loss: 4.5695, Test Accuracy: 2.65%
# Total Computation Time: 27.33 seconds
# Total Communication Time: 0.03 seconds
# Epoch 2, Iteration 1: H_t = 64, G_t = 0.0275, σ_t^2 = 1.6794
# Epoch 2, Iteration 2: H_t = 38, G_t = 0.0364, σ_t^2 = 4.2984
# Epoch 2, Iteration 3: H_t = 64, G_t = 0.6849, σ_t^2 = 7.3888
# Epoch 2, Iteration 4: H_t = 64, G_t = 0.2656, σ_t^2 = 8.9590
#     Worker 0: Train Loss: 4.4110, Train Accuracy: 3.68%
#     Worker 1: Train Loss: 4.4132, Train Accuracy: 3.67%
#     Worker 2: Train Loss: 4.4003, Train Accuracy: 3.77%
#     Worker 3: Train Loss: 4.4137, Train Accuracy: 3.79%
# Epoch 2: Test Loss: 4.1467, Test Accuracy: 7.17%
# Total Computation Time: 54.25 seconds
# Total Communication Time: 0.04 seconds
# Epoch 3, Iteration 1: H_t = 64, G_t = 0.2492, σ_t^2 = 12.1784
# Epoch 3, Iteration 2: H_t = 64, G_t = 0.2399, σ_t^2 = 9.0239
# Epoch 3, Iteration 3: H_t = 4, G_t = -0.1329, σ_t^2 = 10.7964
# Epoch 3, Iteration 4: H_t = 4, G_t = -0.1373, σ_t^2 = 9.6190
#     Worker 0: Train Loss: 4.1313, Train Accuracy: 6.97%
#     Worker 1: Train Loss: 4.1270, Train Accuracy: 6.76%
#     Worker 2: Train Loss: 4.0988, Train Accuracy: 6.90%
#     Worker 3: Train Loss: 4.1322, Train Accuracy: 6.50%
# Epoch 3: Test Loss: 3.9692, Test Accuracy: 9.24%
# Total Computation Time: 77.00 seconds
# Total Communication Time: 0.04 seconds
# Epoch 4, Iteration 1: H_t = 64, G_t = 0.2946, σ_t^2 = 9.5568
# Epoch 4, Iteration 2: H_t = 64, G_t = 0.2638, σ_t^2 = 10.6610
# Epoch 4, Iteration 3: H_t = 64, G_t = 1.7125, σ_t^2 = 9.8849
# Epoch 4, Iteration 4: H_t = 4, G_t = -0.3513, σ_t^2 = 11.5230
#     Worker 0: Train Loss: 3.9808, Train Accuracy: 8.67%
#     Worker 1: Train Loss: 4.0016, Train Accuracy: 8.26%
#     Worker 2: Train Loss: 3.9638, Train Accuracy: 8.83%
#     Worker 3: Train Loss: 3.9900, Train Accuracy: 8.93%
# Epoch 4: Test Loss: 3.8245, Test Accuracy: 12.07%
# Total Computation Time: 99.74 seconds
# Total Communication Time: 0.05 seconds
# Epoch 5, Iteration 1: H_t = 4, G_t = -0.0144, σ_t^2 = 10.9003
# Epoch 5, Iteration 2: H_t = 4, G_t = -0.0416, σ_t^2 = 11.1433
# Epoch 5, Iteration 3: H_t = 64, G_t = 0.5867, σ_t^2 = 12.6024
# Epoch 5, Iteration 4: H_t = 4, G_t = -0.5205, σ_t^2 = 14.2703
# Epoch 5, Iteration 5: H_t = 4, G_t = -0.4423, σ_t^2 = 11.3066
# Epoch 5, Iteration 6: H_t = 64, G_t = 1.6448, σ_t^2 = 10.0041
# Epoch 5, Iteration 7: H_t = 4, G_t = -1.0843, σ_t^2 = 14.7056
# Epoch 5, Iteration 8: H_t = 4, G_t = -0.5759, σ_t^2 = 13.4752
# Epoch 5, Iteration 9: H_t = 4, G_t = -0.1461, σ_t^2 = 12.7558
# Epoch 5, Iteration 10: H_t = 4, G_t = -0.3739, σ_t^2 = 12.2828
# Epoch 5, Iteration 11: H_t = 4, G_t = -0.3461, σ_t^2 = 12.0826
# Epoch 5, Iteration 12: H_t = 4, G_t = -0.2123, σ_t^2 = 12.7269
# Epoch 5, Iteration 13: H_t = 64, G_t = 0.7515, σ_t^2 = 16.6477
# Epoch 5, Iteration 14: H_t = 64, G_t = 0.6937, σ_t^2 = 13.0273
#     Worker 0: Train Loss: 3.8656, Train Accuracy: 10.56%
#     Worker 1: Train Loss: 3.8668, Train Accuracy: 10.60%
#     Worker 2: Train Loss: 3.8171, Train Accuracy: 11.18%
#     Worker 3: Train Loss: 3.8502, Train Accuracy: 10.96%
# Epoch 5: Test Loss: 3.6978, Test Accuracy: 14.08%
# Total Computation Time: 127.94 seconds
# Total Communication Time: 0.07 seconds
# Epoch 6, Iteration 1: H_t = 4, G_t = -0.0581, σ_t^2 = 12.6717
# Epoch 6, Iteration 2: H_t = 64, G_t = 1.2722, σ_t^2 = 12.1636
# Epoch 6, Iteration 3: H_t = 4, G_t = -0.4420, σ_t^2 = 16.8240
# Epoch 6, Iteration 4: H_t = 4, G_t = -0.5130, σ_t^2 = 14.6453
# Epoch 6, Iteration 5: H_t = 64, G_t = 0.2418, σ_t^2 = 12.7398
# Epoch 6, Iteration 6: H_t = 4, G_t = -0.4884, σ_t^2 = 15.0001
#     Worker 0: Train Loss: 3.7602, Train Accuracy: 11.82%
#     Worker 1: Train Loss: 3.7625, Train Accuracy: 11.97%
#     Worker 2: Train Loss: 3.7124, Train Accuracy: 13.16%
#     Worker 3: Train Loss: 3.7699, Train Accuracy: 11.93%
# Epoch 6: Test Loss: 3.5867, Test Accuracy: 16.28%
# Total Computation Time: 152.00 seconds
# Total Communication Time: 0.07 seconds
# Epoch 7, Iteration 1: H_t = 57, G_t = 0.1810, σ_t^2 = 14.2906
# Epoch 7, Iteration 2: H_t = 4, G_t = -1.0616, σ_t^2 = 17.4910
# Epoch 7, Iteration 3: H_t = 64, G_t = 2.5827, σ_t^2 = 12.3467
# Epoch 7, Iteration 4: H_t = 4, G_t = -1.1862, σ_t^2 = 19.0086
# Epoch 7, Iteration 5: H_t = 64, G_t = 1.6974, σ_t^2 = 14.9150
# Epoch 7, Iteration 6: H_t = 4, G_t = -1.0665, σ_t^2 = 17.4043
#     Worker 0: Train Loss: 3.6817, Train Accuracy: 13.22%
#     Worker 1: Train Loss: 3.6753, Train Accuracy: 13.50%
#     Worker 2: Train Loss: 3.6214, Train Accuracy: 14.49%
#     Worker 3: Train Loss: 3.6694, Train Accuracy: 14.00%
# Epoch 7: Test Loss: 3.5063, Test Accuracy: 17.67%
# Total Computation Time: 174.97 seconds
# Total Communication Time: 0.08 seconds
# Epoch 8, Iteration 1: H_t = 4, G_t = -0.1756, σ_t^2 = 16.3134
# Epoch 8, Iteration 2: H_t = 64, G_t = 1.1442, σ_t^2 = 15.7763
# Epoch 8, Iteration 3: H_t = 64, G_t = 0.4139, σ_t^2 = 18.0351
# Epoch 8, Iteration 4: H_t = 64, G_t = 0.8594, σ_t^2 = 17.6181
# Epoch 8, Iteration 5: H_t = 4, G_t = -1.2483, σ_t^2 = 19.4143
#     Worker 0: Train Loss: 3.5838, Train Accuracy: 14.62%
#     Worker 1: Train Loss: 3.5907, Train Accuracy: 15.68%
#     Worker 2: Train Loss: 3.5470, Train Accuracy: 15.81%
#     Worker 3: Train Loss: 3.5995, Train Accuracy: 14.60%
# Epoch 8: Test Loss: 3.4155, Test Accuracy: 19.09%
# Total Computation Time: 198.26 seconds
# Total Communication Time: 0.09 seconds
# Epoch 9, Iteration 1: H_t = 64, G_t = 0.6599, σ_t^2 = 18.3931
# Epoch 9, Iteration 2: H_t = 4, G_t = -0.0875, σ_t^2 = 17.8864
# Epoch 9, Iteration 3: H_t = 64, G_t = 0.3406, σ_t^2 = 15.2644
# Epoch 9, Iteration 4: H_t = 17, G_t = 0.0718, σ_t^2 = 18.8731
# Epoch 9, Iteration 5: H_t = 64, G_t = 0.9757, σ_t^2 = 20.4748
# Epoch 9, Iteration 6: H_t = 4, G_t = -0.9724, σ_t^2 = 22.7418
#     Worker 0: Train Loss: 3.5046, Train Accuracy: 16.23%
#     Worker 1: Train Loss: 3.5322, Train Accuracy: 16.10%
#     Worker 2: Train Loss: 3.4722, Train Accuracy: 16.61%
#     Worker 3: Train Loss: 3.5001, Train Accuracy: 16.44%
# Epoch 9: Test Loss: 3.3390, Test Accuracy: 20.45%
# Total Computation Time: 223.63 seconds
# Total Communication Time: 0.10 seconds
# Epoch 10, Iteration 1: H_t = 64, G_t = 0.4449, σ_t^2 = 15.6710
# Epoch 10, Iteration 2: H_t = 64, G_t = 0.5068, σ_t^2 = 18.3152
# Epoch 10, Iteration 3: H_t = 4, G_t = -0.4891, σ_t^2 = 21.2692
# Epoch 10, Iteration 4: H_t = 64, G_t = 2.4321, σ_t^2 = 16.8837
# Epoch 10, Iteration 5: H_t = 64, G_t = 0.9546, σ_t^2 = 14.8301
#     Worker 0: Train Loss: 3.4305, Train Accuracy: 17.77%
#     Worker 1: Train Loss: 3.4453, Train Accuracy: 17.64%
#     Worker 2: Train Loss: 3.3908, Train Accuracy: 18.55%
#     Worker 3: Train Loss: 3.4462, Train Accuracy: 17.79%
# Epoch 10: Test Loss: 3.2693, Test Accuracy: 21.57%
# Total Computation Time: 247.12 seconds
# Total Communication Time: 0.10 seconds
# Epoch 11, Iteration 1: H_t = 4, G_t = -0.9310, σ_t^2 = 21.7704
# Epoch 11, Iteration 2: H_t = 64, G_t = 0.9953, σ_t^2 = 19.7206
# Epoch 11, Iteration 3: H_t = 64, G_t = 1.2366, σ_t^2 = 22.2566
# Epoch 11, Iteration 4: H_t = 4, G_t = -0.3339, σ_t^2 = 21.8208
#     Worker 0: Train Loss: 3.3635, Train Accuracy: 18.58%
#     Worker 1: Train Loss: 3.3790, Train Accuracy: 18.72%
#     Worker 2: Train Loss: 3.3155, Train Accuracy: 20.38%
#     Worker 3: Train Loss: 3.3789, Train Accuracy: 18.67%
# Epoch 11: Test Loss: 3.1890, Test Accuracy: 22.89%
# Total Computation Time: 269.91 seconds
# Total Communication Time: 0.11 seconds
# Epoch 12, Iteration 1: H_t = 64, G_t = 1.1049, σ_t^2 = 21.8139
# Epoch 12, Iteration 2: H_t = 64, G_t = 0.3690, σ_t^2 = 24.1793
# Epoch 12, Iteration 3: H_t = 64, G_t = 2.1435, σ_t^2 = 19.9628
# Epoch 12, Iteration 4: H_t = 4, G_t = -1.6087, σ_t^2 = 25.1572
#     Worker 0: Train Loss: 3.3085, Train Accuracy: 19.14%
#     Worker 1: Train Loss: 3.3176, Train Accuracy: 19.18%
#     Worker 2: Train Loss: 3.2586, Train Accuracy: 20.46%
#     Worker 3: Train Loss: 3.2887, Train Accuracy: 20.00%
# Epoch 12: Test Loss: 3.1231, Test Accuracy: 24.34%
# Total Computation Time: 293.15 seconds
# Total Communication Time: 0.11 seconds
# Epoch 13, Iteration 1: H_t = 64, G_t = 0.9195, σ_t^2 = 21.9626
# Epoch 13, Iteration 2: H_t = 64, G_t = 1.4388, σ_t^2 = 18.8049
# Epoch 13, Iteration 3: H_t = 64, G_t = 0.4040, σ_t^2 = 24.1048
# Epoch 13, Iteration 4: H_t = 4, G_t = -2.0503, σ_t^2 = 31.1754
#     Worker 0: Train Loss: 3.2564, Train Accuracy: 20.83%
#     Worker 1: Train Loss: 3.2531, Train Accuracy: 20.74%
#     Worker 2: Train Loss: 3.1987, Train Accuracy: 21.59%
#     Worker 3: Train Loss: 3.2681, Train Accuracy: 20.65%
# Epoch 13: Test Loss: 3.0743, Test Accuracy: 24.84%
# Total Computation Time: 317.13 seconds
# Total Communication Time: 0.12 seconds
# Epoch 14, Iteration 1: H_t = 4, G_t = -0.9851, σ_t^2 = 25.2650
# Epoch 14, Iteration 2: H_t = 64, G_t = 0.4148, σ_t^2 = 24.5555
# Epoch 14, Iteration 3: H_t = 4, G_t = -0.3417, σ_t^2 = 28.5419
# Epoch 14, Iteration 4: H_t = 4, G_t = -0.3431, σ_t^2 = 25.8562
# Epoch 14, Iteration 5: H_t = 64, G_t = 1.4797, σ_t^2 = 20.5273
# Epoch 14, Iteration 6: H_t = 42, G_t = 0.2169, σ_t^2 = 23.0614
# Epoch 14, Iteration 7: H_t = 4, G_t = -1.9384, σ_t^2 = 27.0615
# Epoch 14, Iteration 8: H_t = 64, G_t = 2.6859, σ_t^2 = 20.0465
# Epoch 14, Iteration 9: H_t = 4, G_t = -0.1578, σ_t^2 = 24.4601
#     Worker 0: Train Loss: 3.1727, Train Accuracy: 21.75%
#     Worker 1: Train Loss: 3.1997, Train Accuracy: 21.92%
#     Worker 2: Train Loss: 3.1453, Train Accuracy: 22.58%
#     Worker 3: Train Loss: 3.1788, Train Accuracy: 22.04%
# Epoch 14: Test Loss: 2.9991, Test Accuracy: 26.14%
# Total Computation Time: 347.51 seconds
# Total Communication Time: 0.13 seconds
# Epoch 15, Iteration 1: H_t = 38, G_t = 0.2206, σ_t^2 = 25.6340
# Epoch 15, Iteration 2: H_t = 4, G_t = -0.5353, σ_t^2 = 24.8856
# Epoch 15, Iteration 3: H_t = 4, G_t = -0.5934, σ_t^2 = 20.7106
# Epoch 15, Iteration 4: H_t = 64, G_t = 0.4747, σ_t^2 = 21.0116
# Epoch 15, Iteration 5: H_t = 64, G_t = 6.0916, σ_t^2 = 31.1258
# Epoch 15, Iteration 6: H_t = 4, G_t = -0.0708, σ_t^2 = 22.4247
# Epoch 15, Iteration 7: H_t = 7, G_t = 0.0442, σ_t^2 = 26.7159
# Epoch 15, Iteration 8: H_t = 64, G_t = 2.9930, σ_t^2 = 27.2064
# Epoch 15, Iteration 9: H_t = 4, G_t = -0.7761, σ_t^2 = 27.8480
#     Worker 0: Train Loss: 3.1016, Train Accuracy: 23.33%
#     Worker 1: Train Loss: 3.1172, Train Accuracy: 23.14%
#     Worker 2: Train Loss: 3.0689, Train Accuracy: 24.32%
#     Worker 3: Train Loss: 3.1200, Train Accuracy: 23.71%
# Epoch 15: Test Loss: 2.9198, Test Accuracy: 27.80%
# Total Computation Time: 377.06 seconds
# Total Communication Time: 0.14 seconds
# Epoch 16, Iteration 1: H_t = 4, G_t = -1.2192, σ_t^2 = 25.4601
# Epoch 16, Iteration 2: H_t = 64, G_t = 1.5244, σ_t^2 = 20.0498
# Epoch 16, Iteration 3: H_t = 64, G_t = 0.6662, σ_t^2 = 23.5810
# Epoch 16, Iteration 4: H_t = 4, G_t = -0.3735, σ_t^2 = 29.6605
# Epoch 16, Iteration 5: H_t = 4, G_t = -1.1300, σ_t^2 = 29.3208
# Epoch 16, Iteration 6: H_t = 64, G_t = 2.3638, σ_t^2 = 22.4429
# Epoch 16, Iteration 7: H_t = 4, G_t = -0.6579, σ_t^2 = 34.4624
#     Worker 0: Train Loss: 3.0458, Train Accuracy: 24.30%
#     Worker 1: Train Loss: 3.0865, Train Accuracy: 24.61%
#     Worker 2: Train Loss: 3.0223, Train Accuracy: 25.19%
#     Worker 3: Train Loss: 3.0699, Train Accuracy: 24.17%
# Epoch 16: Test Loss: 2.8659, Test Accuracy: 29.22%
# Total Computation Time: 402.13 seconds
# Total Communication Time: 0.15 seconds
# Epoch 17, Iteration 1: H_t = 64, G_t = 0.9800, σ_t^2 = 19.9414
# Epoch 17, Iteration 2: H_t = 4, G_t = -1.3249, σ_t^2 = 33.6839
# Epoch 17, Iteration 3: H_t = 64, G_t = 2.6198, σ_t^2 = 23.9934
# Epoch 17, Iteration 4: H_t = 64, G_t = 1.3887, σ_t^2 = 30.2308
# Epoch 17, Iteration 5: H_t = 4, G_t = -1.4490, σ_t^2 = 27.3155
#     Worker 0: Train Loss: 3.0202, Train Accuracy: 25.10%
#     Worker 1: Train Loss: 3.0297, Train Accuracy: 24.62%
#     Worker 2: Train Loss: 2.9761, Train Accuracy: 26.07%
#     Worker 3: Train Loss: 3.0394, Train Accuracy: 24.72%
# Epoch 17: Test Loss: 2.8563, Test Accuracy: 29.47%
# Total Computation Time: 426.50 seconds
# Total Communication Time: 0.15 seconds
# Epoch 18, Iteration 1: H_t = 4, G_t = -1.7914, σ_t^2 = 28.1171
# Epoch 18, Iteration 2: H_t = 64, G_t = 1.5949, σ_t^2 = 23.5830
# Epoch 18, Iteration 3: H_t = 4, G_t = -1.1886, σ_t^2 = 29.8108
# Epoch 18, Iteration 4: H_t = 64, G_t = 2.4718, σ_t^2 = 25.7075
# Epoch 18, Iteration 5: H_t = 64, G_t = 0.9726, σ_t^2 = 30.5605
# Epoch 18, Iteration 6: H_t = 4, G_t = -1.0851, σ_t^2 = 25.7413
#     Worker 0: Train Loss: 2.9608, Train Accuracy: 25.83%
#     Worker 1: Train Loss: 2.9861, Train Accuracy: 26.14%
#     Worker 2: Train Loss: 2.9479, Train Accuracy: 26.40%
#     Worker 3: Train Loss: 2.9714, Train Accuracy: 26.03%
# Epoch 18: Test Loss: 2.8055, Test Accuracy: 30.28%
# Total Computation Time: 450.78 seconds
# Total Communication Time: 0.16 seconds
# Epoch 19, Iteration 1: H_t = 4, G_t = -1.1236, σ_t^2 = 29.0218
# Epoch 19, Iteration 2: H_t = 64, G_t = 2.1833, σ_t^2 = 22.9444
# Epoch 19, Iteration 3: H_t = 37, G_t = 0.2341, σ_t^2 = 28.0513
# Epoch 19, Iteration 4: H_t = 4, G_t = -0.8445, σ_t^2 = 77.9735
# Epoch 19, Iteration 5: H_t = 64, G_t = 2.4070, σ_t^2 = 27.5047
# Epoch 19, Iteration 6: H_t = 64, G_t = 0.9772, σ_t^2 = 30.2939
# Epoch 19, Iteration 7: H_t = 64, G_t = 0.7402, σ_t^2 = 27.2061
#     Worker 0: Train Loss: 2.9114, Train Accuracy: 27.24%
#     Worker 1: Train Loss: 2.9506, Train Accuracy: 26.86%
#     Worker 2: Train Loss: 2.8784, Train Accuracy: 28.29%
#     Worker 3: Train Loss: 2.9211, Train Accuracy: 26.94%
# Epoch 19: Test Loss: 2.7326, Test Accuracy: 31.51%
# Total Computation Time: 479.70 seconds
# Total Communication Time: 0.17 seconds
# Epoch 20, Iteration 1: H_t = 4, G_t = -1.6971, σ_t^2 = 82.0173
# Epoch 20, Iteration 2: H_t = 4, G_t = -0.7202, σ_t^2 = 25.0506
# Epoch 20, Iteration 3: H_t = 64, G_t = 1.1423, σ_t^2 = 24.5453
# Epoch 20, Iteration 4: H_t = 4, G_t = -1.8400, σ_t^2 = 30.9319
# Epoch 20, Iteration 5: H_t = 50, G_t = 0.3151, σ_t^2 = 27.8635
# Epoch 20, Iteration 6: H_t = 4, G_t = -0.8384, σ_t^2 = 29.7623
# Epoch 20, Iteration 7: H_t = 64, G_t = 0.5167, σ_t^2 = 26.4970
# Epoch 20, Iteration 8: H_t = 4, G_t = -1.2457, σ_t^2 = 29.7265
#     Worker 0: Train Loss: 2.8674, Train Accuracy: 27.67%
#     Worker 1: Train Loss: 2.8912, Train Accuracy: 28.03%
#     Worker 2: Train Loss: 2.8613, Train Accuracy: 28.37%
#     Worker 3: Train Loss: 2.8858, Train Accuracy: 27.70%
# Epoch 20: Test Loss: 2.6981, Test Accuracy: 31.94%
# Total Computation Time: 510.83 seconds
# Total Communication Time: 0.18 seconds
# Epoch 21, Iteration 1: H_t = 4, G_t = -0.9734, σ_t^2 = 36.3597
# Epoch 21, Iteration 2: H_t = 64, G_t = 0.5070, σ_t^2 = 28.6288
# Epoch 21, Iteration 3: H_t = 64, G_t = 0.7205, σ_t^2 = 30.1092
# Epoch 21, Iteration 4: H_t = 4, G_t = -0.0315, σ_t^2 = 35.3831
# Epoch 21, Iteration 5: H_t = 64, G_t = 1.0883, σ_t^2 = 30.2348
# Epoch 21, Iteration 6: H_t = 48, G_t = 0.3807, σ_t^2 = 35.6502
#     Worker 0: Train Loss: 2.8317, Train Accuracy: 28.18%
#     Worker 1: Train Loss: 2.8415, Train Accuracy: 28.16%
#     Worker 2: Train Loss: 2.7985, Train Accuracy: 29.68%
#     Worker 3: Train Loss: 2.8199, Train Accuracy: 29.12%
# Epoch 21: Test Loss: 2.6564, Test Accuracy: 32.77%
# Total Computation Time: 534.69 seconds
# Total Communication Time: 0.19 seconds
# Epoch 22, Iteration 1: H_t = 4, G_t = -1.1907, σ_t^2 = 30.6305
# Epoch 22, Iteration 2: H_t = 64, G_t = 1.0711, σ_t^2 = 28.1219
# Epoch 22, Iteration 3: H_t = 4, G_t = -1.2935, σ_t^2 = 31.5721
# Epoch 22, Iteration 4: H_t = 4, G_t = -0.6666, σ_t^2 = 26.7518
# Epoch 22, Iteration 5: H_t = 4, G_t = -0.1443, σ_t^2 = 28.4050
# Epoch 22, Iteration 6: H_t = 4, G_t = -0.5936, σ_t^2 = 30.7913
# Epoch 22, Iteration 7: H_t = 64, G_t = 0.4689, σ_t^2 = 30.1374
# Epoch 22, Iteration 8: H_t = 30, G_t = 0.2365, σ_t^2 = 35.4234
#     Worker 0: Train Loss: 2.7771, Train Accuracy: 30.00%
#     Worker 1: Train Loss: 2.7928, Train Accuracy: 29.84%
#     Worker 2: Train Loss: 2.7636, Train Accuracy: 30.12%
#     Worker 3: Train Loss: 2.7921, Train Accuracy: 29.62%
# Epoch 22: Test Loss: 2.6334, Test Accuracy: 33.22%
# Total Computation Time: 557.95 seconds
# Total Communication Time: 0.20 seconds
# Epoch 23, Iteration 1: H_t = 64, G_t = 3.4087, σ_t^2 = 40.0724
# Epoch 23, Iteration 2: H_t = 64, G_t = 2.4798, σ_t^2 = 42.0802
# Epoch 23, Iteration 3: H_t = 4, G_t = -0.8042, σ_t^2 = 37.5065
# Epoch 23, Iteration 4: H_t = 64, G_t = 3.4845, σ_t^2 = 36.3973
# Epoch 23, Iteration 5: H_t = 64, G_t = 1.7156, σ_t^2 = 35.7382
#     Worker 0: Train Loss: 2.7414, Train Accuracy: 30.53%
#     Worker 1: Train Loss: 2.7331, Train Accuracy: 30.49%
#     Worker 2: Train Loss: 2.7304, Train Accuracy: 30.85%
#     Worker 3: Train Loss: 2.7527, Train Accuracy: 30.40%
# Epoch 23: Test Loss: 2.5697, Test Accuracy: 34.59%
# Total Computation Time: 584.76 seconds
# Total Communication Time: 0.20 seconds
# Epoch 24, Iteration 1: H_t = 4, G_t = -1.5558, σ_t^2 = 32.4063
# Epoch 24, Iteration 2: H_t = 64, G_t = 2.0623, σ_t^2 = 29.8082
# Epoch 24, Iteration 3: H_t = 64, G_t = 1.1695, σ_t^2 = 31.9640
# Epoch 24, Iteration 4: H_t = 64, G_t = 0.8418, σ_t^2 = 32.3465
#     Worker 0: Train Loss: 2.6970, Train Accuracy: 31.73%
#     Worker 1: Train Loss: 2.7417, Train Accuracy: 30.56%
#     Worker 2: Train Loss: 2.6955, Train Accuracy: 31.26%
#     Worker 3: Train Loss: 2.7301, Train Accuracy: 30.29%
# Epoch 24: Test Loss: 2.5569, Test Accuracy: 35.22%
# Total Computation Time: 608.14 seconds
# Total Communication Time: 0.21 seconds
# Epoch 25, Iteration 1: H_t = 4, G_t = -2.5979, σ_t^2 = 37.1471
# Epoch 25, Iteration 2: H_t = 28, G_t = 0.1882, σ_t^2 = 29.5377
# Epoch 25, Iteration 3: H_t = 64, G_t = 0.7681, σ_t^2 = 41.9055
# Epoch 25, Iteration 4: H_t = 64, G_t = 3.8812, σ_t^2 = 106.4348
# Epoch 25, Iteration 5: H_t = 64, G_t = 0.8783, σ_t^2 = 36.3256
#     Worker 0: Train Loss: 2.6700, Train Accuracy: 31.81%
#     Worker 1: Train Loss: 2.6925, Train Accuracy: 31.67%
#     Worker 2: Train Loss: 2.6322, Train Accuracy: 33.25%
#     Worker 3: Train Loss: 2.6754, Train Accuracy: 31.38%
# Epoch 25: Test Loss: 2.5039, Test Accuracy: 36.36%
# Total Computation Time: 634.75 seconds
# Total Communication Time: 0.22 seconds
# Epoch 26, Iteration 1: H_t = 4, G_t = -1.8063, σ_t^2 = 36.7366
# Epoch 26, Iteration 2: H_t = 4, G_t = -1.2267, σ_t^2 = 31.7455
# Epoch 26, Iteration 3: H_t = 64, G_t = 2.3384, σ_t^2 = 33.2962
# Epoch 26, Iteration 4: H_t = 4, G_t = -0.7100, σ_t^2 = 41.8652
# Epoch 26, Iteration 5: H_t = 64, G_t = 1.8810, σ_t^2 = 35.1765
# Epoch 26, Iteration 6: H_t = 4, G_t = -0.5811, σ_t^2 = 37.0323
#     Worker 0: Train Loss: 2.6307, Train Accuracy: 32.72%
#     Worker 1: Train Loss: 2.6607, Train Accuracy: 32.35%
#     Worker 2: Train Loss: 2.5961, Train Accuracy: 33.50%
#     Worker 3: Train Loss: 2.6613, Train Accuracy: 32.13%
# Epoch 26: Test Loss: 2.4869, Test Accuracy: 36.30%
# Total Computation Time: 658.73 seconds
# Total Communication Time: 0.22 seconds
# Epoch 27, Iteration 1: H_t = 64, G_t = 1.2608, σ_t^2 = 39.0146
# Epoch 27, Iteration 2: H_t = 4, G_t = -1.7710, σ_t^2 = 40.0958
# Epoch 27, Iteration 3: H_t = 4, G_t = -1.1109, σ_t^2 = 33.9313
# Epoch 27, Iteration 4: H_t = 64, G_t = 0.8628, σ_t^2 = 31.8365
# Epoch 27, Iteration 5: H_t = 64, G_t = 2.2538, σ_t^2 = 30.4656
# Epoch 27, Iteration 6: H_t = 4, G_t = -0.4293, σ_t^2 = 32.3131
#     Worker 0: Train Loss: 2.6008, Train Accuracy: 32.93%
#     Worker 1: Train Loss: 2.6290, Train Accuracy: 33.34%
#     Worker 2: Train Loss: 2.5956, Train Accuracy: 33.68%
#     Worker 3: Train Loss: 2.6101, Train Accuracy: 32.56%
# Epoch 27: Test Loss: 2.4531, Test Accuracy: 36.93%
# Total Computation Time: 683.28 seconds
# Total Communication Time: 0.23 seconds
# Epoch 28, Iteration 1: H_t = 4, G_t = -0.4571, σ_t^2 = 34.0688
# Epoch 28, Iteration 2: H_t = 64, G_t = 1.5004, σ_t^2 = 34.0515
# Epoch 28, Iteration 3: H_t = 4, G_t = -1.0180, σ_t^2 = 35.1730
# Epoch 28, Iteration 4: H_t = 64, G_t = 0.7946, σ_t^2 = 27.3259
# Epoch 28, Iteration 5: H_t = 64, G_t = 1.6215, σ_t^2 = 32.9075
# Epoch 28, Iteration 6: H_t = 4, G_t = -0.1483, σ_t^2 = 29.9192
#     Worker 0: Train Loss: 2.5566, Train Accuracy: 34.25%
#     Worker 1: Train Loss: 2.5673, Train Accuracy: 34.07%
#     Worker 2: Train Loss: 2.5432, Train Accuracy: 34.94%
#     Worker 3: Train Loss: 2.5660, Train Accuracy: 34.53%
# Epoch 28: Test Loss: 2.4249, Test Accuracy: 37.68%
# Total Computation Time: 707.40 seconds
# Total Communication Time: 0.24 seconds
# Epoch 29, Iteration 1: H_t = 64, G_t = 0.6880, σ_t^2 = 32.8553
# Epoch 29, Iteration 2: H_t = 4, G_t = -2.5274, σ_t^2 = 38.9804
# Epoch 29, Iteration 3: H_t = 4, G_t = -0.1523, σ_t^2 = 36.2480
# Epoch 29, Iteration 4: H_t = 4, G_t = -0.4568, σ_t^2 = 37.3524
# Epoch 29, Iteration 5: H_t = 4, G_t = -0.5907, σ_t^2 = 31.7060
# Epoch 29, Iteration 6: H_t = 64, G_t = 0.6223, σ_t^2 = 35.3137
# Epoch 29, Iteration 7: H_t = 64, G_t = 4.0907, σ_t^2 = 33.8237
# Epoch 29, Iteration 8: H_t = 64, G_t = 3.0081, σ_t^2 = 36.6130
#     Worker 0: Train Loss: 2.5344, Train Accuracy: 34.39%
#     Worker 1: Train Loss: 2.5600, Train Accuracy: 33.95%
#     Worker 2: Train Loss: 2.5049, Train Accuracy: 35.46%
#     Worker 3: Train Loss: 2.5509, Train Accuracy: 34.20%
# Epoch 29: Test Loss: 2.3925, Test Accuracy: 38.10%
# Total Computation Time: 732.30 seconds
# Total Communication Time: 0.25 seconds
# Epoch 30, Iteration 1: H_t = 52, G_t = 0.3640, σ_t^2 = 31.1026
# Epoch 30, Iteration 2: H_t = 4, G_t = -0.2600, σ_t^2 = 41.3686
# Epoch 30, Iteration 3: H_t = 4, G_t = -0.1261, σ_t^2 = 30.8254
# Epoch 30, Iteration 4: H_t = 64, G_t = 0.9088, σ_t^2 = 35.5138
# Epoch 30, Iteration 5: H_t = 23, G_t = 0.1902, σ_t^2 = 35.7527
# Epoch 30, Iteration 6: H_t = 64, G_t = 1.3915, σ_t^2 = 36.4043
#     Worker 0: Train Loss: 2.5088, Train Accuracy: 34.54%
#     Worker 1: Train Loss: 2.5088, Train Accuracy: 34.74%
#     Worker 2: Train Loss: 2.4825, Train Accuracy: 35.87%
#     Worker 3: Train Loss: 2.5079, Train Accuracy: 34.71%
# Epoch 30: Test Loss: 2.3648, Test Accuracy: 38.84%
# Total Computation Time: 756.95 seconds
# Total Communication Time: 0.26 seconds
# Epoch 31, Iteration 1: H_t = 64, G_t = 1.3869, σ_t^2 = 37.3907
# Epoch 31, Iteration 2: H_t = 4, G_t = -0.7460, σ_t^2 = 32.2233
# Epoch 31, Iteration 3: H_t = 64, G_t = 0.9386, σ_t^2 = 31.7050
# Epoch 31, Iteration 4: H_t = 4, G_t = -0.3327, σ_t^2 = 35.2341
#     Worker 0: Train Loss: 2.4537, Train Accuracy: 35.59%
#     Worker 1: Train Loss: 2.4997, Train Accuracy: 35.46%
#     Worker 2: Train Loss: 2.4591, Train Accuracy: 36.40%
#     Worker 3: Train Loss: 2.5020, Train Accuracy: 35.33%
# Epoch 31: Test Loss: 2.3503, Test Accuracy: 39.06%
# Total Computation Time: 779.74 seconds
# Total Communication Time: 0.26 seconds
# Epoch 32, Iteration 1: H_t = 14, G_t = 0.1161, σ_t^2 = 37.1163
# Epoch 32, Iteration 2: H_t = 18, G_t = 0.1602, σ_t^2 = 39.4091
# Epoch 32, Iteration 3: H_t = 45, G_t = 0.4384, σ_t^2 = 43.7398
# Epoch 32, Iteration 4: H_t = 4, G_t = -1.1739, σ_t^2 = 37.6592
# Epoch 32, Iteration 5: H_t = 64, G_t = 0.6696, σ_t^2 = 39.1570
# Epoch 32, Iteration 6: H_t = 64, G_t = 3.0150, σ_t^2 = 36.1444
# Epoch 32, Iteration 7: H_t = 64, G_t = 4.1465, σ_t^2 = 37.8244
#     Worker 0: Train Loss: 2.4617, Train Accuracy: 36.06%
#     Worker 1: Train Loss: 2.4585, Train Accuracy: 36.47%
#     Worker 2: Train Loss: 2.4341, Train Accuracy: 36.78%
#     Worker 3: Train Loss: 2.4464, Train Accuracy: 36.55%
# Epoch 32: Test Loss: 2.3407, Test Accuracy: 39.10%
# Total Computation Time: 804.89 seconds
# Total Communication Time: 0.27 seconds
# Epoch 33, Iteration 1: H_t = 4, G_t = -0.1520, σ_t^2 = 43.4511
# Epoch 33, Iteration 2: H_t = 64, G_t = 4.5363, σ_t^2 = 33.4850
# Epoch 33, Iteration 3: H_t = 4, G_t = -1.9842, σ_t^2 = 36.9943
# Epoch 33, Iteration 4: H_t = 4, G_t = -1.1170, σ_t^2 = 38.4786
# Epoch 33, Iteration 5: H_t = 64, G_t = 3.2955, σ_t^2 = 30.5917
# Epoch 33, Iteration 6: H_t = 4, G_t = -0.6477, σ_t^2 = 38.2040
#     Worker 0: Train Loss: 2.4136, Train Accuracy: 37.03%
#     Worker 1: Train Loss: 2.4315, Train Accuracy: 36.87%
#     Worker 2: Train Loss: 2.4065, Train Accuracy: 37.80%
#     Worker 3: Train Loss: 2.4380, Train Accuracy: 36.43%
# Epoch 33: Test Loss: 2.3139, Test Accuracy: 40.06%
# Total Computation Time: 828.85 seconds
# Total Communication Time: 0.28 seconds
# Epoch 34, Iteration 1: H_t = 64, G_t = 1.8577, σ_t^2 = 38.8110
# Epoch 34, Iteration 2: H_t = 4, G_t = -0.2653, σ_t^2 = 36.7392
# Epoch 34, Iteration 3: H_t = 4, G_t = -0.6650, σ_t^2 = 34.1559
# Epoch 34, Iteration 4: H_t = 64, G_t = 1.7971, σ_t^2 = 33.2791
# Epoch 34, Iteration 5: H_t = 4, G_t = -0.5055, σ_t^2 = 37.5716
# Epoch 34, Iteration 6: H_t = 64, G_t = 2.1905, σ_t^2 = 36.3882
# Epoch 34, Iteration 7: H_t = 64, G_t = 1.9858, σ_t^2 = 38.5167
#     Worker 0: Train Loss: 2.4005, Train Accuracy: 37.60%
#     Worker 1: Train Loss: 2.4132, Train Accuracy: 37.45%
#     Worker 2: Train Loss: 2.3693, Train Accuracy: 38.22%
#     Worker 3: Train Loss: 2.3985, Train Accuracy: 37.01%
# Epoch 34: Test Loss: 2.3077, Test Accuracy: 40.19%
# Total Computation Time: 853.49 seconds
# Total Communication Time: 0.29 seconds
# Epoch 35, Iteration 1: H_t = 64, G_t = 2.4602, σ_t^2 = 37.1058
# Epoch 35, Iteration 2: H_t = 4, G_t = -0.6655, σ_t^2 = 39.1893
# Epoch 35, Iteration 3: H_t = 24, G_t = 0.1977, σ_t^2 = 36.9372
# Epoch 35, Iteration 4: H_t = 64, G_t = 1.0652, σ_t^2 = 40.4123
# Epoch 35, Iteration 5: H_t = 4, G_t = -1.0393, σ_t^2 = 41.7679
#     Worker 0: Train Loss: 2.3691, Train Accuracy: 37.77%
#     Worker 1: Train Loss: 2.3718, Train Accuracy: 38.02%
#     Worker 2: Train Loss: 2.3475, Train Accuracy: 38.96%
#     Worker 3: Train Loss: 2.3762, Train Accuracy: 37.85%
# Epoch 35: Test Loss: 2.2788, Test Accuracy: 40.89%
# Total Computation Time: 880.12 seconds
# Total Communication Time: 0.29 seconds
# Epoch 36, Iteration 1: H_t = 64, G_t = 4.2050, σ_t^2 = 33.6022
# Epoch 36, Iteration 2: H_t = 4, G_t = -1.5509, σ_t^2 = 40.6772
# Epoch 36, Iteration 3: H_t = 64, G_t = 2.8109, σ_t^2 = 35.4389
# Epoch 36, Iteration 4: H_t = 4, G_t = -1.5621, σ_t^2 = 43.1190
# Epoch 36, Iteration 5: H_t = 53, G_t = 0.4057, σ_t^2 = 34.0069
# Epoch 36, Iteration 6: H_t = 4, G_t = -1.5085, σ_t^2 = 42.2111
# Epoch 36, Iteration 7: H_t = 64, G_t = 0.8913, σ_t^2 = 42.5073
#     Worker 0: Train Loss: 2.3546, Train Accuracy: 38.21%
#     Worker 1: Train Loss: 2.3413, Train Accuracy: 38.75%
#     Worker 2: Train Loss: 2.3170, Train Accuracy: 39.05%
#     Worker 3: Train Loss: 2.3621, Train Accuracy: 38.32%
# Epoch 36: Test Loss: 2.2522, Test Accuracy: 41.30%
# Total Computation Time: 903.32 seconds
# Total Communication Time: 0.30 seconds
# Epoch 37, Iteration 1: H_t = 4, G_t = -1.0446, σ_t^2 = 35.1033
# Epoch 37, Iteration 2: H_t = 17, G_t = 0.1544, σ_t^2 = 38.6636
# Epoch 37, Iteration 3: H_t = 4, G_t = -0.0026, σ_t^2 = 43.1854
# Epoch 37, Iteration 4: H_t = 64, G_t = 1.6968, σ_t^2 = 41.0891
# Epoch 37, Iteration 5: H_t = 4, G_t = -2.7437, σ_t^2 = 54.3228
# Epoch 37, Iteration 6: H_t = 64, G_t = 0.6886, σ_t^2 = 38.2409
# Epoch 37, Iteration 7: H_t = 4, G_t = -1.6494, σ_t^2 = 44.6985
#     Worker 0: Train Loss: 2.3068, Train Accuracy: 39.51%
#     Worker 1: Train Loss: 2.3220, Train Accuracy: 39.56%
#     Worker 2: Train Loss: 2.3006, Train Accuracy: 39.90%
#     Worker 3: Train Loss: 2.3402, Train Accuracy: 38.89%
# Epoch 37: Test Loss: 2.2343, Test Accuracy: 41.94%
# Total Computation Time: 929.25 seconds
# Total Communication Time: 0.31 seconds
# Epoch 38, Iteration 1: H_t = 4, G_t = -1.8877, σ_t^2 = 50.3456
# Epoch 38, Iteration 2: H_t = 64, G_t = 0.8697, σ_t^2 = 32.1491
# Epoch 38, Iteration 3: H_t = 4, G_t = -1.0898, σ_t^2 = 39.0607
# Epoch 38, Iteration 4: H_t = 4, G_t = -0.0786, σ_t^2 = 39.4120
# Epoch 38, Iteration 5: H_t = 4, G_t = -1.6534, σ_t^2 = 43.0009
# Epoch 38, Iteration 6: H_t = 64, G_t = 1.4013, σ_t^2 = 37.6645
# Epoch 38, Iteration 7: H_t = 64, G_t = 1.4613, σ_t^2 = 36.1992
# Epoch 38, Iteration 8: H_t = 64, G_t = 2.3698, σ_t^2 = 40.8934
#     Worker 0: Train Loss: 2.3037, Train Accuracy: 39.14%
#     Worker 1: Train Loss: 2.3016, Train Accuracy: 39.66%
#     Worker 2: Train Loss: 2.2729, Train Accuracy: 40.16%
#     Worker 3: Train Loss: 2.2860, Train Accuracy: 39.91%
# Epoch 38: Test Loss: 2.2353, Test Accuracy: 41.68%
# Total Computation Time: 954.22 seconds
# Total Communication Time: 0.32 seconds
# Epoch 39, Iteration 1: H_t = 4, G_t = -2.2589, σ_t^2 = 47.1657
# Epoch 39, Iteration 2: H_t = 4, G_t = -1.2743, σ_t^2 = 45.1837
# Epoch 39, Iteration 3: H_t = 59, G_t = 0.4917, σ_t^2 = 36.8831
# Epoch 39, Iteration 4: H_t = 23, G_t = 0.2096, σ_t^2 = 40.2044
# Epoch 39, Iteration 5: H_t = 4, G_t = -1.8016, σ_t^2 = 46.8588
# Epoch 39, Iteration 6: H_t = 4, G_t = -0.8680, σ_t^2 = 43.3652
# Epoch 39, Iteration 7: H_t = 64, G_t = 3.2445, σ_t^2 = 39.2628
# Epoch 39, Iteration 8: H_t = 64, G_t = 1.5904, σ_t^2 = 40.4801
#     Worker 0: Train Loss: 2.2666, Train Accuracy: 40.60%
#     Worker 1: Train Loss: 2.2781, Train Accuracy: 40.17%
#     Worker 2: Train Loss: 2.2704, Train Accuracy: 40.53%
#     Worker 3: Train Loss: 2.2974, Train Accuracy: 39.92%
# Epoch 39: Test Loss: 2.2202, Test Accuracy: 42.09%
# Total Computation Time: 980.65 seconds
# Total Communication Time: 0.33 seconds
# Epoch 40, Iteration 1: H_t = 64, G_t = 0.6704, σ_t^2 = 41.3812
# Epoch 40, Iteration 2: H_t = 4, G_t = -0.2810, σ_t^2 = 38.5222
# Epoch 40, Iteration 3: H_t = 64, G_t = 1.1879, σ_t^2 = 39.0491
# Epoch 40, Iteration 4: H_t = 4, G_t = -0.7325, σ_t^2 = 43.3218
#     Worker 0: Train Loss: 2.2550, Train Accuracy: 39.82%
#     Worker 1: Train Loss: 2.2919, Train Accuracy: 39.62%
#     Worker 2: Train Loss: 2.2367, Train Accuracy: 41.20%
#     Worker 3: Train Loss: 2.2771, Train Accuracy: 39.81%
# Epoch 40: Test Loss: 2.1991, Test Accuracy: 42.49%
# Total Computation Time: 1003.74 seconds
# Total Communication Time: 0.33 seconds
# Epoch 41, Iteration 1: H_t = 4, G_t = -0.0430, σ_t^2 = 37.7698
# Epoch 41, Iteration 2: H_t = 64, G_t = 2.1435, σ_t^2 = 34.5369
# Epoch 41, Iteration 3: H_t = 4, G_t = -1.4107, σ_t^2 = 48.2285
# Epoch 41, Iteration 4: H_t = 64, G_t = 0.9959, σ_t^2 = 32.7331
# Epoch 41, Iteration 5: H_t = 4, G_t = -0.3708, σ_t^2 = 128.1528
# Epoch 41, Iteration 6: H_t = 64, G_t = 1.4714, σ_t^2 = 41.1564
# Epoch 41, Iteration 7: H_t = 64, G_t = 4.4928, σ_t^2 = 45.5481
#     Worker 0: Train Loss: 2.2349, Train Accuracy: 40.93%
#     Worker 1: Train Loss: 2.2215, Train Accuracy: 41.70%
#     Worker 2: Train Loss: 2.2239, Train Accuracy: 41.63%
#     Worker 3: Train Loss: 2.2257, Train Accuracy: 40.96%
# Epoch 41: Test Loss: 2.1989, Test Accuracy: 43.15%
# Total Computation Time: 1028.20 seconds
# Total Communication Time: 0.34 seconds
# Epoch 42, Iteration 1: H_t = 64, G_t = 1.0669, σ_t^2 = 40.8840
# Epoch 42, Iteration 2: H_t = 51, G_t = 1.4056, σ_t^2 = 123.5368
# Epoch 42, Iteration 3: H_t = 4, G_t = -2.0344, σ_t^2 = 58.0623
# Epoch 42, Iteration 4: H_t = 4, G_t = -1.6864, σ_t^2 = 42.2942
# Epoch 42, Iteration 5: H_t = 64, G_t = 4.3463, σ_t^2 = 44.8605
# Epoch 42, Iteration 6: H_t = 4, G_t = -2.3827, σ_t^2 = 45.2341
#     Worker 0: Train Loss: 2.2194, Train Accuracy: 41.27%
#     Worker 1: Train Loss: 2.2301, Train Accuracy: 41.38%
#     Worker 2: Train Loss: 2.1994, Train Accuracy: 41.66%
#     Worker 3: Train Loss: 2.2345, Train Accuracy: 41.26%
# Epoch 42: Test Loss: 2.1697, Test Accuracy: 43.52%
# Total Computation Time: 1058.22 seconds
# Total Communication Time: 0.35 seconds
# Epoch 43, Iteration 1: H_t = 64, G_t = 0.8093, σ_t^2 = 34.4423
# Epoch 43, Iteration 2: H_t = 4, G_t = -0.5716, σ_t^2 = 39.8583
# Epoch 43, Iteration 3: H_t = 4, G_t = -1.1905, σ_t^2 = 49.7132
# Epoch 43, Iteration 4: H_t = 4, G_t = -1.2734, σ_t^2 = 39.8088
# Epoch 43, Iteration 5: H_t = 64, G_t = 1.7738, σ_t^2 = 41.0700
# Epoch 43, Iteration 6: H_t = 4, G_t = -2.8745, σ_t^2 = 51.0235
# Epoch 43, Iteration 7: H_t = 64, G_t = 1.0301, σ_t^2 = 50.9930
# Epoch 43, Iteration 8: H_t = 4, G_t = -2.2922, σ_t^2 = 45.4331
#     Worker 0: Train Loss: 2.1648, Train Accuracy: 43.04%
#     Worker 1: Train Loss: 2.1902, Train Accuracy: 42.21%
#     Worker 2: Train Loss: 2.1674, Train Accuracy: 42.83%
#     Worker 3: Train Loss: 2.1868, Train Accuracy: 42.15%
# Epoch 43: Test Loss: 2.1699, Test Accuracy: 43.95%
# Total Computation Time: 1083.37 seconds
# Total Communication Time: 0.36 seconds
# Epoch 44, Iteration 1: H_t = 4, G_t = -0.0651, σ_t^2 = 41.3596
# Epoch 44, Iteration 2: H_t = 64, G_t = 2.1737, σ_t^2 = 38.7539
# Epoch 44, Iteration 3: H_t = 4, G_t = -1.4957, σ_t^2 = 44.4187
# Epoch 44, Iteration 4: H_t = 4, G_t = -1.7297, σ_t^2 = 44.2308
# Epoch 44, Iteration 5: H_t = 64, G_t = 1.4013, σ_t^2 = 41.3062
# Epoch 44, Iteration 6: H_t = 4, G_t = -0.5028, σ_t^2 = 47.7398
# Epoch 44, Iteration 7: H_t = 64, G_t = 0.5791, σ_t^2 = 38.1669
# Epoch 44, Iteration 8: H_t = 4, G_t = -0.7388, σ_t^2 = 43.0755
#     Worker 0: Train Loss: 2.1621, Train Accuracy: 42.72%
#     Worker 1: Train Loss: 2.1634, Train Accuracy: 42.67%
#     Worker 2: Train Loss: 2.1676, Train Accuracy: 42.58%
#     Worker 3: Train Loss: 2.1799, Train Accuracy: 42.42%
# Epoch 44: Test Loss: 2.1397, Test Accuracy: 44.51%
# Total Computation Time: 1108.48 seconds
# Total Communication Time: 0.37 seconds
# Epoch 45, Iteration 1: H_t = 4, G_t = -0.5226, σ_t^2 = 37.5871
# Epoch 45, Iteration 2: H_t = 4, G_t = -1.0726, σ_t^2 = 43.5430
# Epoch 45, Iteration 3: H_t = 4, G_t = -0.1983, σ_t^2 = 43.8410
# Epoch 45, Iteration 4: H_t = 23, G_t = 0.2361, σ_t^2 = 45.2663
# Epoch 45, Iteration 5: H_t = 4, G_t = -1.9531, σ_t^2 = 51.7025
# Epoch 45, Iteration 6: H_t = 29, G_t = 0.2797, σ_t^2 = 42.9665
# Epoch 45, Iteration 7: H_t = 64, G_t = 1.3904, σ_t^2 = 51.1623
# Epoch 45, Iteration 8: H_t = 13, G_t = 0.1337, σ_t^2 = 45.0166
# Epoch 45, Iteration 9: H_t = 4, G_t = -2.3785, σ_t^2 = 48.9838
# Epoch 45, Iteration 10: H_t = 4, G_t = -0.7697, σ_t^2 = 40.0729
# Epoch 45, Iteration 11: H_t = 64, G_t = 1.6849, σ_t^2 = 44.1985
# Epoch 45, Iteration 12: H_t = 4, G_t = -2.8852, σ_t^2 = 54.0132
#     Worker 0: Train Loss: 2.1451, Train Accuracy: 42.93%
#     Worker 1: Train Loss: 2.1429, Train Accuracy: 43.16%
#     Worker 2: Train Loss: 2.1262, Train Accuracy: 43.79%
#     Worker 3: Train Loss: 2.1265, Train Accuracy: 43.74%
# Epoch 45: Test Loss: 2.1417, Test Accuracy: 44.16%
# Total Computation Time: 1134.95 seconds
# Total Communication Time: 0.39 seconds
# Epoch 46, Iteration 1: H_t = 4, G_t = -1.4961, σ_t^2 = 42.7746
# Epoch 46, Iteration 2: H_t = 4, G_t = -1.0482, σ_t^2 = 43.7221
# Epoch 46, Iteration 3: H_t = 64, G_t = 1.1359, σ_t^2 = 43.6693
# Epoch 46, Iteration 4: H_t = 4, G_t = -1.9198, σ_t^2 = 57.2249
# Epoch 46, Iteration 5: H_t = 61, G_t = 0.5522, σ_t^2 = 40.1527
# Epoch 46, Iteration 6: H_t = 64, G_t = 1.3901, σ_t^2 = 54.1264
# Epoch 46, Iteration 7: H_t = 64, G_t = 1.3159, σ_t^2 = 40.2190
#     Worker 0: Train Loss: 2.1265, Train Accuracy: 43.72%
#     Worker 1: Train Loss: 2.1368, Train Accuracy: 43.29%
#     Worker 2: Train Loss: 2.1125, Train Accuracy: 43.44%
#     Worker 3: Train Loss: 2.1252, Train Accuracy: 43.25%
# Epoch 46: Test Loss: 2.1202, Test Accuracy: 44.49%
# Total Computation Time: 1159.46 seconds
# Total Communication Time: 0.39 seconds
# Epoch 47, Iteration 1: H_t = 4, G_t = -0.2772, σ_t^2 = 47.1393
# Epoch 47, Iteration 2: H_t = 4, G_t = -0.5693, σ_t^2 = 38.6797
# Epoch 47, Iteration 3: H_t = 4, G_t = -1.1844, σ_t^2 = 41.5100
# Epoch 47, Iteration 4: H_t = 4, G_t = -1.4205, σ_t^2 = 47.5078
# Epoch 47, Iteration 5: H_t = 44, G_t = 0.3842, σ_t^2 = 38.8901
# Epoch 47, Iteration 6: H_t = 4, G_t = -0.1383, σ_t^2 = 48.5019
# Epoch 47, Iteration 7: H_t = 4, G_t = -0.2299, σ_t^2 = 41.1675
# Epoch 47, Iteration 8: H_t = 63, G_t = 0.6322, σ_t^2 = 44.7808
# Epoch 47, Iteration 9: H_t = 4, G_t = -1.1468, σ_t^2 = 48.0065
# Epoch 47, Iteration 10: H_t = 24, G_t = 0.2757, σ_t^2 = 51.2509
#     Worker 0: Train Loss: 2.1074, Train Accuracy: 43.96%
#     Worker 1: Train Loss: 2.1055, Train Accuracy: 44.04%
#     Worker 2: Train Loss: 2.0814, Train Accuracy: 43.85%
#     Worker 3: Train Loss: 2.1061, Train Accuracy: 43.87%
# Epoch 47: Test Loss: 2.1070, Test Accuracy: 45.11%
# Total Computation Time: 1183.15 seconds
# Total Communication Time: 0.41 seconds
# Epoch 48, Iteration 1: H_t = 4, G_t = -0.3194, σ_t^2 = 40.6260
# Epoch 48, Iteration 2: H_t = 59, G_t = 0.5959, σ_t^2 = 44.7299
# Epoch 48, Iteration 3: H_t = 64, G_t = 3.4976, σ_t^2 = 47.9575
# Epoch 48, Iteration 4: H_t = 32, G_t = 0.3250, σ_t^2 = 44.5854
# Epoch 48, Iteration 5: H_t = 64, G_t = 0.7887, σ_t^2 = 44.4909
# Epoch 48, Iteration 6: H_t = 4, G_t = -0.0530, σ_t^2 = 44.7894
#     Worker 0: Train Loss: 2.0905, Train Accuracy: 44.02%
#     Worker 1: Train Loss: 2.0964, Train Accuracy: 44.23%
#     Worker 2: Train Loss: 2.0650, Train Accuracy: 44.62%
#     Worker 3: Train Loss: 2.0962, Train Accuracy: 43.96%
# Epoch 48: Test Loss: 2.1057, Test Accuracy: 45.33%
# Total Computation Time: 1212.62 seconds
# Total Communication Time: 0.41 seconds
# Epoch 49, Iteration 1: H_t = 58, G_t = 0.5169, σ_t^2 = 39.5543
# Epoch 49, Iteration 2: H_t = 64, G_t = 2.0425, σ_t^2 = 49.0592
# Epoch 49, Iteration 3: H_t = 4, G_t = -0.0737, σ_t^2 = 49.0674
# Epoch 49, Iteration 4: H_t = 4, G_t = -0.6638, σ_t^2 = 43.3286
# Epoch 49, Iteration 5: H_t = 64, G_t = 1.3755, σ_t^2 = 44.9622
# Epoch 49, Iteration 6: H_t = 64, G_t = 2.0368, σ_t^2 = 43.7091
#     Worker 0: Train Loss: 2.0735, Train Accuracy: 44.33%
#     Worker 1: Train Loss: 2.0741, Train Accuracy: 45.11%
#     Worker 2: Train Loss: 2.0654, Train Accuracy: 45.02%
#     Worker 3: Train Loss: 2.0649, Train Accuracy: 45.01%
# Epoch 49: Test Loss: 2.0977, Test Accuracy: 44.98%
# Total Computation Time: 1236.82 seconds
# Total Communication Time: 0.42 seconds
# Epoch 50, Iteration 1: H_t = 34, G_t = 0.4000, σ_t^2 = 51.5840
# Epoch 50, Iteration 2: H_t = 13, G_t = 0.1433, σ_t^2 = 48.1110
# Epoch 50, Iteration 3: H_t = 64, G_t = 1.3129, σ_t^2 = 47.5081
# Epoch 50, Iteration 4: H_t = 64, G_t = 1.7029, σ_t^2 = 48.6877
# Epoch 50, Iteration 5: H_t = 4, G_t = -0.1237, σ_t^2 = 60.4268
#     Worker 0: Train Loss: 2.0708, Train Accuracy: 44.34%
#     Worker 1: Train Loss: 2.0620, Train Accuracy: 44.68%
#     Worker 2: Train Loss: 2.0307, Train Accuracy: 46.07%
#     Worker 3: Train Loss: 2.0664, Train Accuracy: 45.29%
# Epoch 50: Test Loss: 2.0861, Test Accuracy: 45.42%
# Total Computation Time: 1266.13 seconds
# Total Communication Time: 0.43 seconds
# Epoch 51, Iteration 1: H_t = 4, G_t = -1.5032, σ_t^2 = 45.1812
# Epoch 51, Iteration 2: H_t = 64, G_t = 2.4875, σ_t^2 = 39.2082
# Epoch 51, Iteration 3: H_t = 5, G_t = 0.0631, σ_t^2 = 48.8750
# Epoch 51, Iteration 4: H_t = 4, G_t = -1.0127, σ_t^2 = 42.2970
# Epoch 51, Iteration 5: H_t = 64, G_t = 2.7004, σ_t^2 = 45.3717
# Epoch 51, Iteration 6: H_t = 64, G_t = 2.8635, σ_t^2 = 45.2403
# Epoch 51, Iteration 7: H_t = 4, G_t = -1.9574, σ_t^2 = 59.2327
#     Worker 0: Train Loss: 2.0414, Train Accuracy: 46.01%
#     Worker 1: Train Loss: 2.0496, Train Accuracy: 44.86%
#     Worker 2: Train Loss: 2.0282, Train Accuracy: 45.52%
#     Worker 3: Train Loss: 2.0329, Train Accuracy: 45.31%
# Epoch 51: Test Loss: 2.0746, Test Accuracy: 45.34%
# Total Computation Time: 1291.31 seconds
# Total Communication Time: 0.44 seconds
# Epoch 52, Iteration 1: H_t = 25, G_t = 0.2525, σ_t^2 = 44.4792
# Epoch 52, Iteration 2: H_t = 4, G_t = -1.2764, σ_t^2 = 46.7011
# Epoch 52, Iteration 3: H_t = 64, G_t = 0.8652, σ_t^2 = 44.4023
# Epoch 52, Iteration 4: H_t = 64, G_t = 3.1282, σ_t^2 = 51.3267
# Epoch 52, Iteration 5: H_t = 4, G_t = -2.1518, σ_t^2 = 48.1724
# Epoch 52, Iteration 6: H_t = 64, G_t = 2.6983, σ_t^2 = 41.0510
# Epoch 52, Iteration 7: H_t = 4, G_t = -0.4960, σ_t^2 = 43.9374
#     Worker 0: Train Loss: 2.0185, Train Accuracy: 45.42%
#     Worker 1: Train Loss: 2.0457, Train Accuracy: 45.08%
#     Worker 2: Train Loss: 2.0216, Train Accuracy: 46.18%
#     Worker 3: Train Loss: 2.0321, Train Accuracy: 45.87%
# Epoch 52: Test Loss: 2.0641, Test Accuracy: 46.19%
# Total Computation Time: 1318.44 seconds
# Total Communication Time: 0.44 seconds
# Epoch 53, Iteration 1: H_t = 64, G_t = 1.0056, σ_t^2 = 46.5921
# Epoch 53, Iteration 2: H_t = 4, G_t = -1.9620, σ_t^2 = 52.1715
# Epoch 53, Iteration 3: H_t = 4, G_t = -0.1951, σ_t^2 = 42.0473
# Epoch 53, Iteration 4: H_t = 41, G_t = 0.3998, σ_t^2 = 43.3470
# Epoch 53, Iteration 5: H_t = 4, G_t = -1.7126, σ_t^2 = 52.1148
# Epoch 53, Iteration 6: H_t = 4, G_t = -0.1134, σ_t^2 = 42.1655
# Epoch 53, Iteration 7: H_t = 47, G_t = 0.4201, σ_t^2 = 39.5636
# Epoch 53, Iteration 8: H_t = 4, G_t = 0.0404, σ_t^2 = 42.8288
# Epoch 53, Iteration 9: H_t = 64, G_t = 0.7296, σ_t^2 = 39.1684
# Epoch 53, Iteration 10: H_t = 4, G_t = -3.7959, σ_t^2 = 57.2922
#     Worker 0: Train Loss: 1.9916, Train Accuracy: 46.38%
#     Worker 1: Train Loss: 1.9907, Train Accuracy: 46.75%
#     Worker 2: Train Loss: 1.9918, Train Accuracy: 46.32%
#     Worker 3: Train Loss: 2.0238, Train Accuracy: 45.95%
# Epoch 53: Test Loss: 2.0538, Test Accuracy: 46.25%
# Total Computation Time: 1347.34 seconds
# Total Communication Time: 0.46 seconds
# Epoch 54, Iteration 1: H_t = 64, G_t = 0.9787, σ_t^2 = 38.3075
# Epoch 54, Iteration 2: H_t = 64, G_t = 4.0866, σ_t^2 = 52.3951
# Epoch 54, Iteration 3: H_t = 64, G_t = 3.2418, σ_t^2 = 50.4965
# Epoch 54, Iteration 4: H_t = 45, G_t = 0.5140, σ_t^2 = 51.1964
#     Worker 0: Train Loss: 2.0059, Train Accuracy: 46.08%
#     Worker 1: Train Loss: 1.9918, Train Accuracy: 46.57%
#     Worker 2: Train Loss: 1.9855, Train Accuracy: 46.77%
#     Worker 3: Train Loss: 1.9974, Train Accuracy: 46.56%
# Epoch 54: Test Loss: 2.0503, Test Accuracy: 46.32%
# Total Computation Time: 1370.52 seconds
# Total Communication Time: 0.46 seconds
# Epoch 55, Iteration 1: H_t = 52, G_t = 0.6514, σ_t^2 = 55.5403
# Epoch 55, Iteration 2: H_t = 4, G_t = -1.2419, σ_t^2 = 51.2614
# Epoch 55, Iteration 3: H_t = 4, G_t = -0.1376, σ_t^2 = 54.2846
# Epoch 55, Iteration 4: H_t = 4, G_t = -0.0718, σ_t^2 = 42.3545
# Epoch 55, Iteration 5: H_t = 64, G_t = 3.2690, σ_t^2 = 49.4022
# Epoch 55, Iteration 6: H_t = 26, G_t = 0.2786, σ_t^2 = 47.3519
# Epoch 55, Iteration 7: H_t = 64, G_t = 1.7928, σ_t^2 = 49.7908
#     Worker 0: Train Loss: 1.9503, Train Accuracy: 47.14%
#     Worker 1: Train Loss: 1.9650, Train Accuracy: 47.02%
#     Worker 2: Train Loss: 1.9414, Train Accuracy: 47.86%
#     Worker 3: Train Loss: 1.9684, Train Accuracy: 46.99%
# Epoch 55: Test Loss: 2.0485, Test Accuracy: 46.68%
# Total Computation Time: 1393.96 seconds
# Total Communication Time: 0.47 seconds
# Epoch 56, Iteration 1: H_t = 44, G_t = 0.5276, σ_t^2 = 53.8969
# Epoch 56, Iteration 2: H_t = 34, G_t = 0.3902, σ_t^2 = 50.9361
# Epoch 56, Iteration 3: H_t = 33, G_t = 0.4221, σ_t^2 = 56.8034
# Epoch 56, Iteration 4: H_t = 11, G_t = 0.1382, σ_t^2 = 52.9615
# Epoch 56, Iteration 5: H_t = 27, G_t = 0.3085, σ_t^2 = 50.2876
# Epoch 56, Iteration 6: H_t = 4, G_t = -1.4190, σ_t^2 = 51.9369
#     Worker 0: Train Loss: 1.9441, Train Accuracy: 47.15%
#     Worker 1: Train Loss: 1.9579, Train Accuracy: 47.62%
#     Worker 2: Train Loss: 1.9331, Train Accuracy: 48.04%
#     Worker 3: Train Loss: 1.9619, Train Accuracy: 47.45%
# Epoch 56: Test Loss: 2.0382, Test Accuracy: 46.88%
# Total Computation Time: 1419.50 seconds
# Total Communication Time: 0.48 seconds
# Epoch 57, Iteration 1: H_t = 53, G_t = 0.5396, σ_t^2 = 45.0847
# Epoch 57, Iteration 2: H_t = 4, G_t = -1.7658, σ_t^2 = 55.5955
# Epoch 57, Iteration 3: H_t = 64, G_t = 2.3286, σ_t^2 = 44.2564
# Epoch 57, Iteration 4: H_t = 64, G_t = 2.6298, σ_t^2 = 50.7454
# Epoch 57, Iteration 5: H_t = 58, G_t = 0.6116, σ_t^2 = 47.2558
# Epoch 57, Iteration 6: H_t = 4, G_t = -0.6460, σ_t^2 = 52.1375
#     Worker 0: Train Loss: 1.9510, Train Accuracy: 47.39%
#     Worker 1: Train Loss: 1.9484, Train Accuracy: 47.04%
#     Worker 2: Train Loss: 1.9473, Train Accuracy: 47.49%
#     Worker 3: Train Loss: 1.9508, Train Accuracy: 47.46%
# Epoch 57: Test Loss: 2.0285, Test Accuracy: 47.16%
# Total Computation Time: 1448.84 seconds
# Total Communication Time: 0.48 seconds
# Epoch 58, Iteration 1: H_t = 4, G_t = -0.8333, σ_t^2 = 43.3977
# Epoch 58, Iteration 2: H_t = 64, G_t = 1.4202, σ_t^2 = 49.2906
# Epoch 58, Iteration 3: H_t = 64, G_t = 1.0115, σ_t^2 = 58.9109
# Epoch 58, Iteration 4: H_t = 32, G_t = 0.3499, σ_t^2 = 47.8278
# Epoch 58, Iteration 5: H_t = 4, G_t = -0.9533, σ_t^2 = 61.2055
# Epoch 58, Iteration 6: H_t = 4, G_t = -0.3926, σ_t^2 = 51.1942
# Epoch 58, Iteration 7: H_t = 4, G_t = -0.8733, σ_t^2 = 44.5643
# Epoch 58, Iteration 8: H_t = 4, G_t = -0.7799, σ_t^2 = 52.5847
# Epoch 58, Iteration 9: H_t = 4, G_t = -0.8726, σ_t^2 = 50.0409
# Epoch 58, Iteration 10: H_t = 64, G_t = 1.5396, σ_t^2 = 53.1568
# Epoch 58, Iteration 11: H_t = 64, G_t = 2.7853, σ_t^2 = 58.7314
#     Worker 0: Train Loss: 1.9287, Train Accuracy: 47.63%
#     Worker 1: Train Loss: 1.9326, Train Accuracy: 48.15%
#     Worker 2: Train Loss: 1.8904, Train Accuracy: 48.71%
#     Worker 3: Train Loss: 1.9174, Train Accuracy: 48.04%
# Epoch 58: Test Loss: 2.0182, Test Accuracy: 47.48%
# Total Computation Time: 1478.14 seconds
# Total Communication Time: 0.50 seconds
# Epoch 59, Iteration 1: H_t = 4, G_t = -1.6706, σ_t^2 = 55.2439
# Epoch 59, Iteration 2: H_t = 44, G_t = 0.4848, σ_t^2 = 48.9371
# Epoch 59, Iteration 3: H_t = 64, G_t = 0.8725, σ_t^2 = 49.4716
# Epoch 59, Iteration 4: H_t = 4, G_t = -1.5775, σ_t^2 = 58.9020
# Epoch 59, Iteration 5: H_t = 64, G_t = 0.7688, σ_t^2 = 45.0310
# Epoch 59, Iteration 6: H_t = 64, G_t = 0.9819, σ_t^2 = 50.2205
#     Worker 0: Train Loss: 1.9093, Train Accuracy: 48.16%
#     Worker 1: Train Loss: 1.9032, Train Accuracy: 48.66%
#     Worker 2: Train Loss: 1.8945, Train Accuracy: 48.54%
#     Worker 3: Train Loss: 1.9299, Train Accuracy: 47.69%
# Epoch 59: Test Loss: 2.0081, Test Accuracy: 47.53%
# Total Computation Time: 1506.59 seconds
# Total Communication Time: 0.51 seconds
# Epoch 60, Iteration 1: H_t = 64, G_t = 0.9039, σ_t^2 = 52.2508
# Epoch 60, Iteration 2: H_t = 64, G_t = 2.4050, σ_t^2 = 56.2372
# Epoch 60, Iteration 3: H_t = 23, G_t = 0.2732, σ_t^2 = 53.0847
# Epoch 60, Iteration 4: H_t = 4, G_t = -0.0135, σ_t^2 = 51.7396
#     Worker 0: Train Loss: 1.8947, Train Accuracy: 48.69%
#     Worker 1: Train Loss: 1.8927, Train Accuracy: 48.73%
#     Worker 2: Train Loss: 1.8999, Train Accuracy: 48.76%
#     Worker 3: Train Loss: 1.9196, Train Accuracy: 48.32%
# Epoch 60: Test Loss: 2.0091, Test Accuracy: 47.24%
# Total Computation Time: 1531.71 seconds
# Total Communication Time: 0.51 seconds
# Epoch 61, Iteration 1: H_t = 64, G_t = 3.6003, σ_t^2 = 42.4929
# Epoch 61, Iteration 2: H_t = 4, G_t = -0.9690, σ_t^2 = 53.2910
# Epoch 61, Iteration 3: H_t = 22, G_t = 0.2559, σ_t^2 = 51.1258
# Epoch 61, Iteration 4: H_t = 4, G_t = -0.3022, σ_t^2 = 53.9145
# Epoch 61, Iteration 5: H_t = 4, G_t = -0.8797, σ_t^2 = 51.0566
# Epoch 61, Iteration 6: H_t = 64, G_t = 2.2561, σ_t^2 = 46.8468
# Epoch 61, Iteration 7: H_t = 4, G_t = -1.5835, σ_t^2 = 57.2941
# Epoch 61, Iteration 8: H_t = 4, G_t = -0.9482, σ_t^2 = 44.6138
# Epoch 61, Iteration 9: H_t = 64, G_t = 1.6517, σ_t^2 = 48.3055
# Epoch 61, Iteration 10: H_t = 4, G_t = -1.5772, σ_t^2 = 67.0828
#     Worker 0: Train Loss: 1.8718, Train Accuracy: 49.01%
#     Worker 1: Train Loss: 1.8587, Train Accuracy: 49.47%
#     Worker 2: Train Loss: 1.8401, Train Accuracy: 49.87%
#     Worker 3: Train Loss: 1.8712, Train Accuracy: 49.26%
# Epoch 61: Test Loss: 1.9993, Test Accuracy: 47.51%
# Total Computation Time: 1559.93 seconds
# Total Communication Time: 0.52 seconds
# Epoch 62, Iteration 1: H_t = 64, G_t = 3.6625, σ_t^2 = 55.9644
# Epoch 62, Iteration 2: H_t = 64, G_t = 0.8290, σ_t^2 = 53.7532
# Epoch 62, Iteration 3: H_t = 64, G_t = 2.0167, σ_t^2 = 58.4688
# Epoch 62, Iteration 4: H_t = 64, G_t = 0.6700, σ_t^2 = 45.6161
#     Worker 0: Train Loss: 1.8565, Train Accuracy: 49.46%
#     Worker 1: Train Loss: 1.8612, Train Accuracy: 49.62%
#     Worker 2: Train Loss: 1.8583, Train Accuracy: 49.66%
#     Worker 3: Train Loss: 1.8791, Train Accuracy: 48.90%
# Epoch 62: Test Loss: 1.9951, Test Accuracy: 47.98%
# Total Computation Time: 1582.98 seconds
# Total Communication Time: 0.53 seconds
# Epoch 63, Iteration 1: H_t = 4, G_t = -0.9671, σ_t^2 = 59.4069
# Epoch 63, Iteration 2: H_t = 64, G_t = 2.2579, σ_t^2 = 47.9054
# Epoch 63, Iteration 3: H_t = 22, G_t = 0.2849, σ_t^2 = 56.2764
# Epoch 63, Iteration 4: H_t = 4, G_t = -2.0621, σ_t^2 = 58.4209
# ...
# Total Computation Time: 3418.66 seconds
# Total Communication Time: 1.23 seconds
# Epoch 135, Iteration 1: H_t = 4, G_t = -0.2101, σ_t^2 = 83.2582
# Epoch 135, Iteration 2: H_t = 4, G_t = -0.5378, σ_t^2 = 103.7380
# Epoch 135, Iteration 3: H_t = 4, G_t = -1.5757, σ_t^2 = 93.1008
# Epoch 135, Iteration 4: H_t = 26, G_t = 0.5097, σ_t^2 = 87.8373
# Epoch 135, Iteration 5: H_t = 4, G_t = -0.1987, σ_t^2 = 84.1913
# Epoch 135, Iteration 6: H_t = 64, G_t = 1.4382, σ_t^2 = 86.0420
# Epoch 135, Iteration 7: H_t = 4, G_t = -0.5269, σ_t^2 = 92.1306
# Epoch 135, Iteration 8: H_t = 64, G_t = 1.2647, σ_t^2 = 84.4875
# Epoch 135, Iteration 9: H_t = 4, G_t = -1.3648, σ_t^2 = 93.5520
# Epoch 135, Iteration 10: H_t = 4, G_t = -0.9224, σ_t^2 = 80.0451
# Epoch 135, Iteration 11: H_t = 50, G_t = 0.9979, σ_t^2 = 89.1913
# Epoch 135, Iteration 12: H_t = 64, G_t = 2.0686, σ_t^2 = 92.4148
#     Worker 0: Train Loss: 1.2537, Train Accuracy: 64.36%
#     Worker 1: Train Loss: 1.2554, Train Accuracy: 64.70%
#     Worker 2: Train Loss: 1.2450, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2581, Train Accuracy: 64.35%
# Epoch 135: Test Loss: 1.9369, Test Accuracy: 51.00%
# Total Computation Time: 3445.75 seconds
# Total Communication Time: 1.25 seconds
# Epoch 136, Iteration 1: H_t = 4, G_t = -1.0190, σ_t^2 = 101.8710
# Epoch 136, Iteration 2: H_t = 7, G_t = 0.1402, σ_t^2 = 88.8463
# Epoch 136, Iteration 3: H_t = 4, G_t = 0.0840, σ_t^2 = 86.1539
# Epoch 136, Iteration 4: H_t = 64, G_t = 4.8442, σ_t^2 = 87.1552
# Epoch 136, Iteration 5: H_t = 19, G_t = 0.3569, σ_t^2 = 83.7472
# Epoch 136, Iteration 6: H_t = 4, G_t = -0.6237, σ_t^2 = 106.2817
# Epoch 136, Iteration 7: H_t = 64, G_t = 1.2652, σ_t^2 = 85.8859
# Epoch 136, Iteration 8: H_t = 4, G_t = -0.3966, σ_t^2 = 102.3025
#     Worker 0: Train Loss: 1.2280, Train Accuracy: 65.26%
#     Worker 1: Train Loss: 1.2335, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2369, Train Accuracy: 64.74%
#     Worker 3: Train Loss: 1.2406, Train Accuracy: 64.81%
# Epoch 136: Test Loss: 1.9342, Test Accuracy: 51.11%
# Total Computation Time: 3472.00 seconds
# Total Communication Time: 1.25 seconds
# Epoch 137, Iteration 1: H_t = 4, G_t = -1.1579, σ_t^2 = 92.1899
# Epoch 137, Iteration 2: H_t = 45, G_t = 0.8680, σ_t^2 = 85.7074
# Epoch 137, Iteration 3: H_t = 4, G_t = -1.8082, σ_t^2 = 98.3502
# Epoch 137, Iteration 4: H_t = 4, G_t = -1.3887, σ_t^2 = 89.1924
# Epoch 137, Iteration 5: H_t = 4, G_t = -1.9186, σ_t^2 = 84.0350
# Epoch 137, Iteration 6: H_t = 6, G_t = 0.1413, σ_t^2 = 92.7405
# Epoch 137, Iteration 7: H_t = 4, G_t = -0.5551, σ_t^2 = 96.3075
# Epoch 137, Iteration 8: H_t = 4, G_t = -0.1567, σ_t^2 = 86.9139
# Epoch 137, Iteration 9: H_t = 4, G_t = -1.2575, σ_t^2 = 102.0293
# Epoch 137, Iteration 10: H_t = 4, G_t = -0.1916, σ_t^2 = 91.8093
# Epoch 137, Iteration 11: H_t = 4, G_t = -1.6810, σ_t^2 = 98.7915
# Epoch 137, Iteration 12: H_t = 64, G_t = 1.6842, σ_t^2 = 86.3018
# Epoch 137, Iteration 13: H_t = 64, G_t = 4.1102, σ_t^2 = 91.5007
# Epoch 137, Iteration 14: H_t = 4, G_t = -1.4895, σ_t^2 = 106.2415
#     Worker 0: Train Loss: 1.2373, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2534, Train Accuracy: 64.72%
#     Worker 2: Train Loss: 1.2441, Train Accuracy: 64.47%
#     Worker 3: Train Loss: 1.2513, Train Accuracy: 64.79%
# Epoch 137: Test Loss: 1.9344, Test Accuracy: 51.07%
# Total Computation Time: 3497.76 seconds
# Total Communication Time: 1.27 seconds
# Epoch 138, Iteration 1: H_t = 4, G_t = -0.7287, σ_t^2 = 87.3322
# Epoch 138, Iteration 2: H_t = 4, G_t = -2.3598, σ_t^2 = 92.4066
# Epoch 138, Iteration 3: H_t = 64, G_t = 2.6903, σ_t^2 = 87.9291
# Epoch 138, Iteration 4: H_t = 4, G_t = -0.4303, σ_t^2 = 85.6855
# Epoch 138, Iteration 5: H_t = 4, G_t = -0.3668, σ_t^2 = 91.3360
# Epoch 138, Iteration 6: H_t = 4, G_t = -0.7074, σ_t^2 = 96.7964
# Epoch 138, Iteration 7: H_t = 4, G_t = -1.7700, σ_t^2 = 92.2061
# Epoch 138, Iteration 8: H_t = 64, G_t = 2.3853, σ_t^2 = 82.2054
# Epoch 138, Iteration 9: H_t = 4, G_t = -0.8507, σ_t^2 = 75.5178
# Epoch 138, Iteration 10: H_t = 64, G_t = 2.5396, σ_t^2 = 81.5730
# Epoch 138, Iteration 11: H_t = 4, G_t = -0.3862, σ_t^2 = 76.2137
#     Worker 0: Train Loss: 1.2452, Train Accuracy: 64.10%
#     Worker 1: Train Loss: 1.2316, Train Accuracy: 65.49%
#     Worker 2: Train Loss: 1.2329, Train Accuracy: 65.39%
#     Worker 3: Train Loss: 1.2419, Train Accuracy: 64.57%
# Epoch 138: Test Loss: 1.9344, Test Accuracy: 50.96%
# Total Computation Time: 3523.89 seconds
# Total Communication Time: 1.29 seconds
# Epoch 139, Iteration 1: H_t = 4, G_t = -0.9778, σ_t^2 = 84.7458
# Epoch 139, Iteration 2: H_t = 60, G_t = 1.3110, σ_t^2 = 98.1158
# Epoch 139, Iteration 3: H_t = 4, G_t = -0.6342, σ_t^2 = 87.2925
# Epoch 139, Iteration 4: H_t = 4, G_t = -0.0422, σ_t^2 = 96.5447
# Epoch 139, Iteration 5: H_t = 11, G_t = 0.2068, σ_t^2 = 81.4530
# Epoch 139, Iteration 6: H_t = 61, G_t = 1.2607, σ_t^2 = 92.1569
# Epoch 139, Iteration 7: H_t = 4, G_t = -0.2225, σ_t^2 = 90.0241
# Epoch 139, Iteration 8: H_t = 64, G_t = 2.0245, σ_t^2 = 91.1798
# Epoch 139, Iteration 9: H_t = 4, G_t = -0.0997, σ_t^2 = 82.6647
#     Worker 0: Train Loss: 1.2541, Train Accuracy: 63.89%
#     Worker 1: Train Loss: 1.2392, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2377, Train Accuracy: 64.54%
#     Worker 3: Train Loss: 1.2446, Train Accuracy: 64.80%
# Epoch 139: Test Loss: 1.9339, Test Accuracy: 51.09%
# Total Computation Time: 3548.88 seconds
# Total Communication Time: 1.30 seconds
# Epoch 140, Iteration 1: H_t = 4, G_t = -1.1961, σ_t^2 = 83.3711
# Epoch 140, Iteration 2: H_t = 32, G_t = 0.6102, σ_t^2 = 83.9238
# Epoch 140, Iteration 3: H_t = 4, G_t = -0.5232, σ_t^2 = 85.5745
# Epoch 140, Iteration 4: H_t = 4, G_t = -0.4028, σ_t^2 = 101.7010
# Epoch 140, Iteration 5: H_t = 4, G_t = -0.5797, σ_t^2 = 91.4789
# Epoch 140, Iteration 6: H_t = 4, G_t = -1.0664, σ_t^2 = 102.9839
# Epoch 140, Iteration 7: H_t = 4, G_t = -0.2137, σ_t^2 = 86.6328
# Epoch 140, Iteration 8: H_t = 64, G_t = 1.2497, σ_t^2 = 83.3153
# Epoch 140, Iteration 9: H_t = 4, G_t = -3.2056, σ_t^2 = 94.6037
# Epoch 140, Iteration 10: H_t = 64, G_t = 1.6345, σ_t^2 = 83.1690
# Epoch 140, Iteration 11: H_t = 64, G_t = 1.2954, σ_t^2 = 85.0708
# Epoch 140, Iteration 12: H_t = 22, G_t = 0.5113, σ_t^2 = 104.2368
#     Worker 0: Train Loss: 1.2395, Train Accuracy: 64.74%
#     Worker 1: Train Loss: 1.2361, Train Accuracy: 64.86%
#     Worker 2: Train Loss: 1.2399, Train Accuracy: 64.90%
#     Worker 3: Train Loss: 1.2431, Train Accuracy: 64.98%
# Epoch 140: Test Loss: 1.9351, Test Accuracy: 51.09%
# Total Computation Time: 3578.10 seconds
# Total Communication Time: 1.31 seconds
# Epoch 141, Iteration 1: H_t = 4, G_t = -0.5265, σ_t^2 = 82.9473
# Epoch 141, Iteration 2: H_t = 34, G_t = 0.6334, σ_t^2 = 83.4832
# Epoch 141, Iteration 3: H_t = 4, G_t = -1.6030, σ_t^2 = 99.6772
# Epoch 141, Iteration 4: H_t = 4, G_t = -1.0213, σ_t^2 = 106.5861
# Epoch 141, Iteration 5: H_t = 64, G_t = 1.3708, σ_t^2 = 91.7751
# Epoch 141, Iteration 6: H_t = 37, G_t = 0.8092, σ_t^2 = 97.0534
# Epoch 141, Iteration 7: H_t = 4, G_t = -0.3666, σ_t^2 = 80.4102
# Epoch 141, Iteration 8: H_t = 4, G_t = -2.5898, σ_t^2 = 103.7727
# Epoch 141, Iteration 9: H_t = 64, G_t = 2.6465, σ_t^2 = 79.5580
# Epoch 141, Iteration 10: H_t = 64, G_t = 1.2558, σ_t^2 = 86.1079
#     Worker 0: Train Loss: 1.2248, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2295, Train Accuracy: 65.43%
#     Worker 2: Train Loss: 1.2459, Train Accuracy: 64.84%
#     Worker 3: Train Loss: 1.2402, Train Accuracy: 64.59%
# Epoch 141: Test Loss: 1.9336, Test Accuracy: 51.04%
# Total Computation Time: 3605.65 seconds
# Total Communication Time: 1.33 seconds
# Epoch 142, Iteration 1: H_t = 40, G_t = 0.8880, σ_t^2 = 98.5482
# Epoch 142, Iteration 2: H_t = 4, G_t = -0.7734, σ_t^2 = 92.4850
# Epoch 142, Iteration 3: H_t = 64, G_t = 6.3397, σ_t^2 = 97.8765
# Epoch 142, Iteration 4: H_t = 32, G_t = 0.6184, σ_t^2 = 86.1312
# Epoch 142, Iteration 5: H_t = 23, G_t = 0.5128, σ_t^2 = 97.8577
#     Worker 0: Train Loss: 1.2360, Train Accuracy: 64.43%
#     Worker 1: Train Loss: 1.2243, Train Accuracy: 65.20%
#     Worker 2: Train Loss: 1.2287, Train Accuracy: 65.36%
#     Worker 3: Train Loss: 1.2420, Train Accuracy: 64.99%
# Epoch 142: Test Loss: 1.9348, Test Accuracy: 50.97%
# Total Computation Time: 3629.12 seconds
# Total Communication Time: 1.33 seconds
# Epoch 143, Iteration 1: H_t = 4, G_t = -1.6036, σ_t^2 = 91.1999
# Epoch 143, Iteration 2: H_t = 30, G_t = 0.7205, σ_t^2 = 105.0874
# Epoch 143, Iteration 3: H_t = 28, G_t = 0.5187, σ_t^2 = 82.8942
# Epoch 143, Iteration 4: H_t = 64, G_t = 1.5967, σ_t^2 = 102.2098
# Epoch 143, Iteration 5: H_t = 4, G_t = -1.1878, σ_t^2 = 95.8418
# Epoch 143, Iteration 6: H_t = 4, G_t = -1.9997, σ_t^2 = 89.5231
# Epoch 143, Iteration 7: H_t = 64, G_t = 2.0107, σ_t^2 = 95.8901
# Epoch 143, Iteration 8: H_t = 4, G_t = -0.6491, σ_t^2 = 99.3710
#     Worker 0: Train Loss: 1.2368, Train Accuracy: 65.19%
#     Worker 1: Train Loss: 1.2395, Train Accuracy: 65.13%
#     Worker 2: Train Loss: 1.2490, Train Accuracy: 65.01%
#     Worker 3: Train Loss: 1.2435, Train Accuracy: 64.70%
# Epoch 143: Test Loss: 1.9345, Test Accuracy: 51.02%
# Total Computation Time: 3654.62 seconds
# Total Communication Time: 1.34 seconds
# Epoch 144, Iteration 1: H_t = 4, G_t = -1.0951, σ_t^2 = 95.0519
# Epoch 144, Iteration 2: H_t = 4, G_t = -2.4814, σ_t^2 = 102.1177
# Epoch 144, Iteration 3: H_t = 4, G_t = -0.7258, σ_t^2 = 84.0929
# Epoch 144, Iteration 4: H_t = 49, G_t = 1.1148, σ_t^2 = 101.1912
# Epoch 144, Iteration 5: H_t = 4, G_t = -0.3456, σ_t^2 = 99.1329
# Epoch 144, Iteration 6: H_t = 59, G_t = 1.0684, σ_t^2 = 80.8566
# Epoch 144, Iteration 7: H_t = 4, G_t = -3.1903, σ_t^2 = 101.2434
# Epoch 144, Iteration 8: H_t = 4, G_t = -3.6240, σ_t^2 = 95.6412
# Epoch 144, Iteration 9: H_t = 4, G_t = -5.2105, σ_t^2 = 262.2446
# Epoch 144, Iteration 10: H_t = 21, G_t = 0.4273, σ_t^2 = 90.1647
# Epoch 144, Iteration 11: H_t = 34, G_t = 0.7576, σ_t^2 = 98.7191
# Epoch 144, Iteration 12: H_t = 64, G_t = 1.7278, σ_t^2 = 78.8518
# Epoch 144, Iteration 13: H_t = 39, G_t = 0.9146, σ_t^2 = 104.4305
#     Worker 0: Train Loss: 1.2458, Train Accuracy: 64.64%
#     Worker 1: Train Loss: 1.2194, Train Accuracy: 65.75%
#     Worker 2: Train Loss: 1.2368, Train Accuracy: 64.89%
#     Worker 3: Train Loss: 1.2402, Train Accuracy: 64.90%
# Epoch 144: Test Loss: 1.9354, Test Accuracy: 51.04%
# Total Computation Time: 3684.85 seconds
# Total Communication Time: 1.36 seconds
# Epoch 145, Iteration 1: H_t = 4, G_t = 0.0842, σ_t^2 = 83.8397
# Epoch 145, Iteration 2: H_t = 32, G_t = 0.6640, σ_t^2 = 90.7951
# Epoch 145, Iteration 3: H_t = 4, G_t = -0.9291, σ_t^2 = 98.8560
# Epoch 145, Iteration 4: H_t = 64, G_t = 3.0895, σ_t^2 = 94.8407
# Epoch 145, Iteration 5: H_t = 24, G_t = 0.5231, σ_t^2 = 94.6085
# Epoch 145, Iteration 6: H_t = 64, G_t = 1.4972, σ_t^2 = 90.8613
# Epoch 145, Iteration 7: H_t = 4, G_t = -1.5572, σ_t^2 = 98.9173
#     Worker 0: Train Loss: 1.2419, Train Accuracy: 64.67%
#     Worker 1: Train Loss: 1.2428, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2336, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2323, Train Accuracy: 64.91%
# Epoch 145: Test Loss: 1.9352, Test Accuracy: 50.99%
# Total Computation Time: 3711.27 seconds
# Total Communication Time: 1.37 seconds
# Epoch 146, Iteration 1: H_t = 64, G_t = 1.6503, σ_t^2 = 95.5276
# Epoch 146, Iteration 2: H_t = 23, G_t = 0.5059, σ_t^2 = 98.3009
# Epoch 146, Iteration 3: H_t = 24, G_t = 0.5421, σ_t^2 = 97.7077
# Epoch 146, Iteration 4: H_t = 64, G_t = 5.3835, σ_t^2 = 106.5168
# Epoch 146, Iteration 5: H_t = 4, G_t = -2.3809, σ_t^2 = 92.9404
# Epoch 146, Iteration 6: H_t = 4, G_t = -0.5347, σ_t^2 = 86.4745
# Epoch 146, Iteration 7: H_t = 4, G_t = -0.5880, σ_t^2 = 81.0893
# Epoch 146, Iteration 8: H_t = 4, G_t = -2.6454, σ_t^2 = 86.6922
# Epoch 146, Iteration 9: H_t = 64, G_t = 1.5623, σ_t^2 = 80.2087
# Epoch 146, Iteration 10: H_t = 64, G_t = 4.1410, σ_t^2 = 79.0504
#     Worker 0: Train Loss: 1.2412, Train Accuracy: 64.47%
#     Worker 1: Train Loss: 1.2369, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.2273, Train Accuracy: 65.42%
#     Worker 3: Train Loss: 1.2475, Train Accuracy: 64.60%
# Epoch 146: Test Loss: 1.9355, Test Accuracy: 51.06%
# Total Computation Time: 3740.94 seconds
# Total Communication Time: 1.38 seconds
# Epoch 147, Iteration 1: H_t = 64, G_t = 1.3544, σ_t^2 = 87.3934
# Epoch 147, Iteration 2: H_t = 4, G_t = -0.9192, σ_t^2 = 92.6297
# Epoch 147, Iteration 3: H_t = 4, G_t = -2.3111, σ_t^2 = 107.7300
# Epoch 147, Iteration 4: H_t = 4, G_t = -0.2492, σ_t^2 = 90.3597
# Epoch 147, Iteration 5: H_t = 64, G_t = 1.4345, σ_t^2 = 84.6571
# Epoch 147, Iteration 6: H_t = 4, G_t = -2.2755, σ_t^2 = 87.0037
#     Worker 0: Train Loss: 1.2447, Train Accuracy: 64.61%
#     Worker 1: Train Loss: 1.2373, Train Accuracy: 65.06%
#     Worker 2: Train Loss: 1.2324, Train Accuracy: 64.83%
#     Worker 3: Train Loss: 1.2487, Train Accuracy: 64.57%
# Epoch 147: Test Loss: 1.9355, Test Accuracy: 51.00%
# Total Computation Time: 3764.45 seconds
# Total Communication Time: 1.39 seconds
# Epoch 148, Iteration 1: H_t = 4, G_t = -3.8815, σ_t^2 = 97.3557
# Epoch 148, Iteration 2: H_t = 51, G_t = 1.0629, σ_t^2 = 92.4138
# Epoch 148, Iteration 3: H_t = 62, G_t = 1.2228, σ_t^2 = 87.9928
# Epoch 148, Iteration 4: H_t = 62, G_t = 1.2747, σ_t^2 = 91.8263
# Epoch 148, Iteration 5: H_t = 4, G_t = -1.9594, σ_t^2 = 103.4072
# Epoch 148, Iteration 6: H_t = 42, G_t = 0.9155, σ_t^2 = 96.9051
# Epoch 148, Iteration 7: H_t = 9, G_t = 0.1867, σ_t^2 = 91.0858
#     Worker 0: Train Loss: 1.2293, Train Accuracy: 64.78%
#     Worker 1: Train Loss: 1.2360, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2252, Train Accuracy: 65.24%
#     Worker 3: Train Loss: 1.2497, Train Accuracy: 64.95%
# Epoch 148: Test Loss: 1.9356, Test Accuracy: 51.01%
# Total Computation Time: 3791.29 seconds
# Total Communication Time: 1.40 seconds
# Epoch 149, Iteration 1: H_t = 4, G_t = -1.8638, σ_t^2 = 92.4159
# Epoch 149, Iteration 2: H_t = 4, G_t = -0.6878, σ_t^2 = 90.7056
# Epoch 149, Iteration 3: H_t = 4, G_t = 0.0578, σ_t^2 = 90.3744
# Epoch 149, Iteration 4: H_t = 12, G_t = 0.2258, σ_t^2 = 84.1482
# Epoch 149, Iteration 5: H_t = 4, G_t = -0.4733, σ_t^2 = 92.3249
# Epoch 149, Iteration 6: H_t = 4, G_t = -1.7957, σ_t^2 = 85.7371
# Epoch 149, Iteration 7: H_t = 4, G_t = 0.0807, σ_t^2 = 86.4724
# Epoch 149, Iteration 8: H_t = 4, G_t = -2.2989, σ_t^2 = 101.9610
# Epoch 149, Iteration 9: H_t = 4, G_t = -0.7041, σ_t^2 = 99.8725
# Epoch 149, Iteration 10: H_t = 4, G_t = 0.0694, σ_t^2 = 95.6019
# Epoch 149, Iteration 11: H_t = 4, G_t = -0.4416, σ_t^2 = 96.5679
# Epoch 149, Iteration 12: H_t = 57, G_t = 1.1520, σ_t^2 = 89.4564
# Epoch 149, Iteration 13: H_t = 4, G_t = -1.7500, σ_t^2 = 94.7601
# Epoch 149, Iteration 14: H_t = 64, G_t = 1.4885, σ_t^2 = 81.7715
# Epoch 149, Iteration 15: H_t = 4, G_t = -0.4780, σ_t^2 = 83.9739
# Epoch 149, Iteration 16: H_t = 64, G_t = 2.8051, σ_t^2 = 92.3274
# Epoch 149, Iteration 17: H_t = 39, G_t = 0.7070, σ_t^2 = 81.5363
#     Worker 0: Train Loss: 1.2377, Train Accuracy: 64.56%
#     Worker 1: Train Loss: 1.2349, Train Accuracy: 64.80%
#     Worker 2: Train Loss: 1.2473, Train Accuracy: 64.80%
#     Worker 3: Train Loss: 1.2309, Train Accuracy: 65.32%
# Epoch 149: Test Loss: 1.9354, Test Accuracy: 51.03%
# Total Computation Time: 3820.45 seconds
# Total Communication Time: 1.42 seconds
# Epoch 150, Iteration 1: H_t = 64, G_t = 1.4789, σ_t^2 = 87.1967
# Epoch 150, Iteration 2: H_t = 4, G_t = -0.2851, σ_t^2 = 79.6306
# Epoch 150, Iteration 3: H_t = 4, G_t = -0.1449, σ_t^2 = 92.2493
# Epoch 150, Iteration 4: H_t = 4, G_t = -0.8805, σ_t^2 = 91.9440
# Epoch 150, Iteration 5: H_t = 64, G_t = 3.6619, σ_t^2 = 94.2083
# Epoch 150, Iteration 6: H_t = 4, G_t = 0.0056, σ_t^2 = 95.6043
# Epoch 150, Iteration 7: H_t = 4, G_t = -3.4766, σ_t^2 = 91.4857
# Epoch 150, Iteration 8: H_t = 64, G_t = 1.5910, σ_t^2 = 92.9267
# Epoch 150, Iteration 9: H_t = 4, G_t = -2.3241, σ_t^2 = 89.1610
#     Worker 0: Train Loss: 1.2494, Train Accuracy: 64.41%
#     Worker 1: Train Loss: 1.2301, Train Accuracy: 65.13%
#     Worker 2: Train Loss: 1.2327, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2434, Train Accuracy: 64.95%
# Epoch 150: Test Loss: 1.9354, Test Accuracy: 51.05%
# Total Computation Time: 3850.40 seconds
# Total Communication Time: 1.43 seconds
